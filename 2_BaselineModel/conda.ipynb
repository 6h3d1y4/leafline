# %%
from osgeo import gdal

print(gdal.VersionInfo())
# Out:
# 3120400

# %%
#check working dir - should be root folder of project, also containing cloned github from deeptrees
import os
os.getcwd()
# Out:
# 'c:\\pythonProjects\\openCampus\\applied_machine_learning\\baseline'

# %%
pip install -r DeepTrees-main/requirements.txt
# Out:
# ...
#   Using cached torch-2.9.1-cp311-cp311-win_amd64.whl.metadata (30 kB)
# ...
#   Using cached torchmetrics-1.8.2-py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached torchvision-0.24.1-cp311-cp311-win_amd64.whl.metadata (5.9 kB)
# ...
#   Using cached numpy-2.4.1-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# ...
#   Using cached segmentation_models_pytorch-0.5.0-py3-none-any.whl.metadata (17 kB)
# ...
#   Using cached xarray-2025.12.0-py3-none-any.whl.metadata (12 kB)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# ...

# %%
pip install rioxarray
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %run DeepTrees-main/scripts/test.py --config-name=inference_kiel.yaml
# Out:
# name: baseline-kiel
# output_dir: results
# data:
#   _target_: deeptrees.dataloading.datamodule.TreeCrownDelineationDataModule
#   rasters: /data/botGarten
#   masks: null
#   outlines: null
#   distance_transforms: null
#   batch_size: 1
#   test_indices: null
#   dim_ordering: CHW
#   ndvi_config:
#     concatenate: true
#     rescale: false
#     red: 0
#     nir: 3
#   gci_config:
#     concatenate: false
#     rescale: false
#     red: 0
#     green: 1
#     nir: 3
#   hue_config:
#     concatenate: false
#     rescale: false
#     red: 0
#     green: 1
#     blue: 2
#   divide_by: 255
#   dilate_outlines: false
#   augment_eval: {}
#   ground_truth_config:
#     labels: null
#   num_workers: 8
# pretrained_model: Unet-resnet18_epochs=209_lr=0.0001_width=224_bs=32_divby=255_custom_color_augs_k=3_jitted.pt
# model:
#   _target_: deeptrees.model.deeptrees_model.DeepTreesModel
#   num_backbones: 1
#   in_channels: 5
#   architecture: Unet
#   backbone: resnet18
# ...

# %%
# !dir /s Unet-resnet18_epochs=209_lr=0.0001_width=224_bs=32_divby=255_custom_color_augs_k=3_jitted.pt
# Out:
#  Datentr�ger in Laufwerk C: ist Local Disk
#  Volumeseriennummer: 6C57-0013
# Datei nicht gefunden

# %%
import deeptrees
from deeptrees import predict

predict(image_path=["C:/pythonProjects/openCampus/applied_machine_learning/baseline/DeepTrees-main/data/botGarten/tile_0_0.tif"], config_path="C:/pythonProjects/openCampus/applied_machine_learning/baseline/DeepTrees-main/config/predict/5-channel.yaml")
# Out:
# [2026-06-23 15:02:29,374][deeptrees.inference][INFO] - Loaded Configuration:
# [2026-06-23 15:02:29,384][deeptrees.inference][INFO] - data:
#   ndvi_config:
#     concatenate: true
#     rescale: false
#     red: 0
#     nir: 3
#   gci_config:
#     concatenate: false
#     rescale: false
#     red: 0
#     green: 1
#     nir: 3
#   hue_config:
#     concatenate: false
#     rescale: false
#     red: 0
#     green: 1
#     blue: 2
#   divide_by: 255
#   dilate_outlines: false
#   augment_eval: {}
#   in_memory: false
# model:
#   num_backbones: 1
#   in_channels: 5
#   architecture: Unet
#   backbone: resnet18
#   apply_sigmoid: false
# download_pretrained_model: true
# pretrained_model_path: ./pretrained_models
# pretrained_model_name: Unet-resnet18_epochs=209_lr=0.0001_width=224_bs=32_divby=255_custom_color_augs_k=3_jitted.pt
# polygon_extraction:
#   min_dist: 10
#   mask_exp: 2
#   outline_multiplier: 5
#   outline_exp: 1
#   dist_exp: 0.5
#   area_min: 3
#   sigma: 2
# ...
